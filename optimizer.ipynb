# %%
from models import *
import requests
import folium
import folium.plugins
import uuid
from typing import List, Optional, Dict, Tuple
from IPython.display import display
import random

# Constants
MAPBOX_OPTIMIZATION_API_URL = "https://api.mapbox.com/optimized-trips/v1/mapbox/driving-traffic/"
MAPBOX_DIRECTIONS_API_URL = "https://api.mapbox.com/directions/v5/mapbox/driving-traffic/"
MAPBOX_ACCESS_TOKEN = "pk.eyJ1IjoicGVuZGxhIiwiYSI6ImNtOXNuNjV2NjAyNjYyanM5M2Fjb24xYTAifQ.7RqcSLC1TxVWdeZMj8QkTw"

# %%
class Test:
    """Test class for unit testing."""
    def __init__(self, optimizer: MapboxOptimizer):
        self.optimizer = optimizer

    def add_single_rider(self, driver: Driver, rider: Rider) -> None:
        """Test adding a single rider to a driver's ride."""
        print(f"\nAdding single rider {rider.name} to {driver.name}'s ride...")
        ride_manager = RideManager(self.optimizer)
        success = ride_manager.add_rider_to_ride(driver.ride, rider)
        if success:
            print(f"Successfully added {rider.name} to the ride.")
            # Step 4: Display updated ride
            print(f"\nUpdated Ride for {driver.name}:")
        else:
            print(f"Failed to add {rider.name} to the ride.")

    def add_riders_in_order(self, driver: Driver, riders: List[Rider]) -> None:
        """Test adding riders to a driver's ride in order."""
        print(f"\nAdding riders in order to {driver.name}'s ride...")
        ride_manager = RideManager(self.optimizer)
        for rider in riders:
            success = ride_manager.add_rider_to_ride(driver.ride, rider)
            if success:
                print(f"Successfully added {rider.name} to the ride.")
            else:
                print(f"Failed to add {rider.name} to the ride.")
        ride_manager.display_ride_info(driver.ride)

# %%
WORKPLACES = {
    "STIHL": [48.8315, 9.3095],
    "MERCEDES": [48.7833, 9.2250]
}

optimizer = MapboxOptimizer(MAPBOX_ACCESS_TOKEN)
ride_manager = RideManager(optimizer)

drivers = [
    Driver("Mohsen", [48.686722, 8.993101], WORKPLACES["STIHL"], "STIHL", max_detour_minutes=30, max_riders=3, optimizer=optimizer),
    Driver("Karim", [48.8316, 9.1670], WORKPLACES["STIHL"], "STIHL", max_detour_minutes=25, max_riders=2, optimizer=optimizer),
    Driver("Kamilia", [48.9000, 9.2000], WORKPLACES["STIHL"], "STIHL", max_detour_minutes=35, max_riders=4, optimizer=optimizer),
    Driver("Mahmoud", [48.7465, 9.1066], WORKPLACES["MERCEDES"], "MERCEDES", max_detour_minutes=20, max_riders=2, optimizer=optimizer),
    Driver("Skander", [48.7833, 9.1667], WORKPLACES["MERCEDES"], "MERCEDES", max_detour_minutes=50, max_riders=3, optimizer=optimizer),
]
riders = [
    Rider("Mongi", [48.7833, 9.1833], WORKPLACES["STIHL"], "STIHL"),
    Rider("Ammar", [48.6833, 9.0167], WORKPLACES["STIHL"], "STIHL"),
    Rider("Faya", [48.9100, 9.1400], WORKPLACES["STIHL"], "STIHL"),
    Rider("Samir", [48.7500, 9.1500], WORKPLACES["MERCEDES"], "MERCEDES"),
    Rider("Ghassen", [48.7400, 9.3000], WORKPLACES["MERCEDES"], "MERCEDES"),
]

# %%
test = Test(optimizer)
for i in range(3):
    driver = Driver("Mohsen", [48.686722, 8.993101], WORKPLACES["STIHL"], "STIHL", max_detour_minutes=30, max_riders=3, optimizer=optimizer)
    riders = [
        Rider("Mongi", [48.7833, 9.1833], WORKPLACES["STIHL"], "STIHL"),
        Rider("Ammar", [48.6833, 9.0167], WORKPLACES["STIHL"], "STIHL"),
        Rider("Faya", [48.9100, 9.1400], WORKPLACES["STIHL"], "STIHL"),
        Rider("Samir", [48.7500, 9.1500], WORKPLACES["MERCEDES"], "MERCEDES"),
        Rider("Ghassen", [48.7400, 9.3000], WORKPLACES["MERCEDES"], "MERCEDES"),
        Rider("Slim", [48.777490, 9.159607], WORKPLACES["STIHL"], "STIHL"),
        Rider("Fraj", [48.776868, 9.206385], WORKPLACES["STIHL"], "STIHL"),
        Rider("Khalil", [48.732164, 9.114031], WORKPLACES["STIHL"], "STIHL")
    ]
    random.shuffle(riders)
    test.add_riders_in_order(driver, riders)
# Out:
# Adding riders in order to Mohsen's ride...
# Successfully added Fraj to the ride.
# Successfully added Ammar to the ride.
# Successfully added Khalil to the ride.
# Rider Ghassen does not match workplace STIHL
# Failed to add Ghassen to the ride.
# Rider Samir does not match workplace STIHL
# Failed to add Samir to the ride.
# Driver Mohsen's ride is full (max 3 riders).
# Failed to add Faya to the ride.
# Driver Mohsen's ride is full (max 3 riders).
# Failed to add Slim to the ride.
# Driver Mohsen's ride is full (max 3 riders).
# Failed to add Mongi to the ride.
#
# ============================================================
# Ride Summary for Mohsen
# ============================================================
#
# General Information:
# - Driver: Mohsen
# - Workplace: STIHL (48.831500, 9.309500)
# - Max Riders: 3
# - Max Detour: 30.00 minutes
# - Riders: Fraj, Ammar, Khalil
# - Total Distance: 38.62 km
# - Total Duration: 63.95 minutes
# - Detour: 23.69 minutes
# - Direct Duration (no riders): 40.25 minutes
#
# Pickup Order:
# 1. Mohsen (Driver) at (48.686722, 8.993101)
# 2. Khalil (Rider) at (48.732164, 9.114031)
# 3. Fraj (Rider) at (48.776868, 9.206385)
# 4. Ammar (Rider) at (48.683300, 9.016700)
# 5. STIHL (Workplace) at (48.831500, 9.309500)
#
# Segment Durations:
# - Mohsen to Khalil: 6.04 minutes
# - Khalil to Fraj: 17.32 minutes
# - Fraj to Ammar: 22.26 minutes
# - Ammar to STIHL: 18.32 minutes
#
# Failed Assignment Attempts:
# - Rider Ghassen does not match workplace STIHL
# - Rider Samir does not match workplace STIHL
# - Driver Mohsen's ride is full (max 3 riders)
# - Driver Mohsen's ride is full (max 3 riders)
# - Driver Mohsen's ride is full (max 3 riders)
#
# Generating Route Map...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f51b1657a2435ff5de8bd9dd8a43c19c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f51b1657a2435ff5de8bd9dd8a43c19c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f51b1657a2435ff5de8bd9dd8a43c19c = L.map(
#                 &quot;map_f51b1657a2435ff5de8bd9dd8a43c19c&quot;,
#                 {
#                     center: [48.7421108, 9.127943400000001],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e6d781ed0620010ac9fcf1fee3d940ab = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e6d781ed0620010ac9fcf1fee3d940ab.addTo(map_f51b1657a2435ff5de8bd9dd8a43c19c);
#
#
#             var marker_f7e6802ae967820dfd6f264248999608 = L.marker(
#                 [48.686722, 8.993101],
#                 {
# }
#             ).addTo(map_f51b1657a2435ff5de8bd9dd8a43c19c);
#
#
#             var icon_7fbe05d927f1ee73d5e7e2712a5fed19 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_6119026237e4d529b448360c5bb3f848 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd4c8dcf02e721a8a2a54b12fb4455e0 = $(`&lt;div id=&quot;html_fd4c8dcf02e721a8a2a54b12fb4455e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Driver: Mohsen&lt;/div&gt;`)[0];
#                 popup_6119026237e4d529b448360c5bb3f848.setContent(html_fd4c8dcf02e721a8a2a54b12fb4455e0);
#
#
#
#         marker_f7e6802ae967820dfd6f264248999608.bindPopup(popup_6119026237e4d529b448360c5bb3f848)
#         ;
#
#
#
#
#                 marker_f7e6802ae967820dfd6f264248999608.setIcon(icon_7fbe05d927f1ee73d5e7e2712a5fed19);
#
#
#             var marker_9981e87b491da0625da5df8ea714daf6 = L.marker(
#                 [48.776868, 9.206385],
#                 {
# }
#             ).addTo(map_f51b1657a2435ff5de8bd9dd8a43c19c);
#
#
#             var icon_da08f4be67ec338232eea1898015abf5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_500778fc0b74a67827db920b1a3295a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27d849af003badee822a7693be5c2597 = $(`&lt;div id=&quot;html_27d849af003badee822a7693be5c2597&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rider: Fraj&lt;/div&gt;`)[0];
#                 popup_500778fc0b74a67827db920b1a3295a6.setContent(html_27d849af003badee822a7693be5c2597);
#
#
#
#         marker_9981e87b491da0625da5df8ea714daf6.bindPopup(popup_500778fc0b74a67827db920b1a3295a6)
#         ;
#
#
#
#
#                 marker_9981e87b491da0625da5df8ea714daf6.setIcon(icon_da08f4be67ec338232eea1898015abf5);
#
#
#             var marker_f3a61e16e2798219baf97459aadbffc8 = L.marker(
#                 [48.6833, 9.0167],
#                 {
# }
#             ).addTo(map_f51b1657a2435ff5de8bd9dd8a43c19c);
#
#
#             var icon_165de94c187a2368e0da7f83f3b43ea3 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_66eb1100e51d961a123be7494b96257f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6880595859289e69ccb15082f085af8a = $(`&lt;div id=&quot;html_6880595859289e69ccb15082f085af8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rider: Ammar&lt;/div&gt;`)[0];
#                 popup_66eb1100e51d961a123be7494b96257f.setContent(html_6880595859289e69ccb15082f085af8a);
#
#
#
#         marker_f3a61e16e2798219baf97459aadbffc8.bindPopup(popup_66eb1100e51d961a123be7494b96257f)
#         ;
#
#
#
#
#                 marker_f3a61e16e2798219baf97459aadbffc8.setIcon(icon_165de94c187a2368e0da7f83f3b43ea3);
#
#
#             var marker_e90c2ef109aa5dc8cb2bef5cd2f6ba3d = L.marker(
#                 [48.732164, 9.114031],
#                 {
# }
#             ).addTo
# Adding riders in order to Mohsen's ride...
# Successfully added Faya to the ride.
# Adding Khalil exceeds max detour of 30 minutes.
# Failed to add Khalil to the ride.
# Adding Fraj exceeds max detour of 30 minutes.
# Failed to add Fraj to the ride.
# Adding Ammar exceeds max detour of 30 minutes.
# Failed to add Ammar to the ride.
# Adding Mongi exceeds max detour of 30 minutes.
# Failed to add Mongi to the ride.
# Rider Ghassen does not match workplace STIHL
# Failed to add Ghassen to the ride.
# Rider Samir does not match workplace STIHL
# Failed to add Samir to the ride.
# Adding Slim exceeds max detour of 30 minutes.
# Failed to add Slim to the ride.
#
# ============================================================
# Ride Summary for Mohsen
# ============================================================
#
# General Information:
# - Driver: Mohsen
# - Workplace: STIHL (48.831500, 9.309500)
# - Max Riders: 3
# - Max Detour: 30.00 minutes
# - Riders: Faya
# - Total Distance: 56.20 km
# - Total Duration: 70.15 minutes
# - Detour: 29.90 minutes
# - Direct Duration (no riders): 40.25 minutes
#
# Pickup Order:
# 1. Mohsen (Driver) at (48.686722, 8.993101)
# 2. Faya (Rider) at (48.910000, 9.140000)
# 3. STIHL (Workplace) at (48.831500, 9.309500)
#
# Segment Durations:
# - Mohsen to Faya: 37.63 minutes
# - Faya to STIHL: 32.52 minutes
#
# Failed Assignment Attempts:
# - Adding Khalil exceeds max detour of 30 minutes
# - Adding Fraj exceeds max detour of 30 minutes
# - Adding Ammar exceeds max detour of 30 minutes
# - Adding Mongi exceeds max detour of 30 minutes
# - Rider Ghassen does not match workplace STIHL
# - Rider Samir does not match workplace STIHL
# - Adding Slim exceeds max detour of 30 minutes
#
# Generating Route Map...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_33abf0b313c3cc0c50c5847fda8700f6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_33abf0b313c3cc0c50c5847fda8700f6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_33abf0b313c3cc0c50c5847fda8700f6 = L.map(
#                 &quot;map_33abf0b313c3cc0c50c5847fda8700f6&quot;,
#                 {
#                     center: [48.80940733333333, 9.147533666666666],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6071fd03ea8936466b05916ebe710939 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6071fd03ea8936466b05916ebe710939.addTo(map_33abf0b313c3cc0c50c5847fda8700f6);
#
#
#             var marker_bde4667083d3247c13b22bab6eb58659 = L.marker(
#                 [48.686722, 8.993101],
#                 {
# }
#             ).addTo(map_33abf0b313c3cc0c50c5847fda8700f6);
#
#
#             var icon_e0cb39f702a5be1510a705817b8b96de = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_862c41329e8895d20cdf7995e897c819 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58dab21024421fad9b00ffee84c77dc0 = $(`&lt;div id=&quot;html_58dab21024421fad9b00ffee84c77dc0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Driver: Mohsen&lt;/div&gt;`)[0];
#                 popup_862c41329e8895d20cdf7995e897c819.setContent(html_58dab21024421fad9b00ffee84c77dc0);
#
#
#
#         marker_bde4667083d3247c13b22bab6eb58659.bindPopup(popup_862c41329e8895d20cdf7995e897c819)
#         ;
#
#
#
#
#                 marker_bde4667083d3247c13b22bab6eb58659.setIcon(icon_e0cb39f702a5be1510a705817b8b96de);
#
#
#             var marker_174376f9f2a7c6fb1d63bff03a31afd5 = L.marker(
#                 [48.91, 9.14],
#                 {
# }
#             ).addTo(map_33abf0b313c3cc0c50c5847fda8700f6);
#
#
#             var icon_ba9bf473fafd7091de0b2aa61d585080 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_34fa2c206823fa2ebe5c544403a49e35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb1a211621f510bc456743b88c46c699 = $(`&lt;div id=&quot;html_eb1a211621f510bc456743b88c46c699&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rider: Faya&lt;/div&gt;`)[0];
#                 popup_34fa2c206823fa2ebe5c544403a49e35.setContent(html_eb1a211621f510bc456743b88c46c699);
#
#
#
#         marker_174376f9f2a7c6fb1d63bff03a31afd5.bindPopup(popup_34fa2c206823fa2ebe5c544403a49e35)
#         ;
#
#
#
#
#                 marker_174376f9f2a7c6fb1d63bff03a31afd5.setIcon(icon_ba9bf473fafd7091de0b2aa61d585080);
#
#
#             var marker_e127ff45719a35e123390e68cda4d9da = L.marker(
#                 [48.8315, 9.3095],
#                 {
# }
#             ).addTo(map_33abf0b313c3cc0c50c5847fda8700f6);
#
#
#             var icon_439b9d44fb375d368825e5f9b6611eb5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_2fc5d5a78d645cc441c8147f67bc636a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cdad4d4b5f50969de5dd8ab55ba84c3c = $(`&lt;div id=&quot;html_cdad4d4b5f50969de5dd8ab55ba84c3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Workplace: STIHL&lt;/div&gt;`)[0];
#                 popup_2fc5d5a78d645cc441c8147f67bc636a.setContent(html_cdad4d4b5f50969de5dd8ab55ba84c3c);
#
#
#
#         marker_e127ff45719a35e123390e68cda4d9da.bindPopup(popup_2fc5d5a78d645cc441c8147f67bc636a)
#         ;
#
#
#
#
#                 marker_e127ff45719a35e123390e68cda4d9da.setIcon(icon_439b9d44fb375d368825e5f9b6611eb5);
#
#
#             ant_path_a3d6f6a2fcda7228ea3d79b0eb3eca82 = L.polyline.antPath(
#               [[48.686721, 8.993101], [48.686492, 8.994958], [48.6865
# Adding riders in order to Mohsen's ride...
# Successfully added Mongi to the ride.
# Successfully added Ammar to the ride.
# Rider Ghassen does not match workplace STIHL
# Failed to add Ghassen to the ride.
# Successfully added Khalil to the ride.
# Driver Mohsen's ride is full (max 3 riders).
# Failed to add Faya to the ride.
# Driver Mohsen's ride is full (max 3 riders).
# Failed to add Fraj to the ride.
# Driver Mohsen's ride is full (max 3 riders).
# Failed to add Slim to the ride.
# Rider Samir does not match workplace STIHL
# Failed to add Samir to the ride.
#
# ============================================================
# Ride Summary for Mohsen
# ============================================================
#
# General Information:
# - Driver: Mohsen
# - Workplace: STIHL (48.831500, 9.309500)
# - Max Riders: 3
# - Max Detour: 30.00 minutes
# - Riders: Mongi, Ammar, Khalil
# - Total Distance: 39.49 km
# - Total Duration: 64.08 minutes
# - Detour: 23.82 minutes
# - Direct Duration (no riders): 40.25 minutes
#
# Pickup Order:
# 1. Mohsen (Driver) at (48.686722, 8.993101)
# 2. Khalil (Rider) at (48.732164, 9.114031)
# 3. Mongi (Rider) at (48.783300, 9.183300)
# 4. Ammar (Rider) at (48.683300, 9.016700)
# 5. STIHL (Workplace) at (48.831500, 9.309500)
#
# Segment Durations:
# - Mohsen to Khalil: 6.04 minutes
# - Khalil to Mongi: 17.32 minutes
# - Mongi to Ammar: 18.31 minutes
# - Ammar to STIHL: 22.40 minutes
#
# Failed Assignment Attempts:
# - Rider Ghassen does not match workplace STIHL
# - Driver Mohsen's ride is full (max 3 riders)
# - Driver Mohsen's ride is full (max 3 riders)
# - Driver Mohsen's ride is full (max 3 riders)
# - Rider Samir does not match workplace STIHL
#
# Generating Route Map...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ccd94f20dcbc4548db4a5567fe4605bc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ccd94f20dcbc4548db4a5567fe4605bc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ccd94f20dcbc4548db4a5567fe4605bc = L.map(
#                 &quot;map_ccd94f20dcbc4548db4a5567fe4605bc&quot;,
#                 {
#                     center: [48.743397200000004, 9.1233264],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_04b1fe30ffde116df01a3f98670ea9f4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_04b1fe30ffde116df01a3f98670ea9f4.addTo(map_ccd94f20dcbc4548db4a5567fe4605bc);
#
#
#             var marker_5eb2f230ceeffbd5c6c4341a860aec6f = L.marker(
#                 [48.686722, 8.993101],
#                 {
# }
#             ).addTo(map_ccd94f20dcbc4548db4a5567fe4605bc);
#
#
#             var icon_86ce30f3cc0c3b93ac524f11caa12891 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_178f83232dac4bb8b61c89356fc6e0a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce942d368f8803e46e13ac4c9b7db000 = $(`&lt;div id=&quot;html_ce942d368f8803e46e13ac4c9b7db000&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Driver: Mohsen&lt;/div&gt;`)[0];
#                 popup_178f83232dac4bb8b61c89356fc6e0a7.setContent(html_ce942d368f8803e46e13ac4c9b7db000);
#
#
#
#         marker_5eb2f230ceeffbd5c6c4341a860aec6f.bindPopup(popup_178f83232dac4bb8b61c89356fc6e0a7)
#         ;
#
#
#
#
#                 marker_5eb2f230ceeffbd5c6c4341a860aec6f.setIcon(icon_86ce30f3cc0c3b93ac524f11caa12891);
#
#
#             var marker_1cae750df3132098108826b26f260325 = L.marker(
#                 [48.7833, 9.1833],
#                 {
# }
#             ).addTo(map_ccd94f20dcbc4548db4a5567fe4605bc);
#
#
#             var icon_9a1940452b06dbd25d07c2c7ee2301ee = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_879fa6fef20b72795f8fb80548e889c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c8693ac0edcdd941224123091b8b698 = $(`&lt;div id=&quot;html_9c8693ac0edcdd941224123091b8b698&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rider: Mongi&lt;/div&gt;`)[0];
#                 popup_879fa6fef20b72795f8fb80548e889c8.setContent(html_9c8693ac0edcdd941224123091b8b698);
#
#
#
#         marker_1cae750df3132098108826b26f260325.bindPopup(popup_879fa6fef20b72795f8fb80548e889c8)
#         ;
#
#
#
#
#                 marker_1cae750df3132098108826b26f260325.setIcon(icon_9a1940452b06dbd25d07c2c7ee2301ee);
#
#
#             var marker_2d1d04f6e0b7a3e997374e8655d40d07 = L.marker(
#                 [48.6833, 9.0167],
#                 {
# }
#             ).addTo(map_ccd94f20dcbc4548db4a5567fe4605bc);
#
#
#             var icon_9d8cc9e9a6caaf7e00519f1395cd6b7b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_1e28a01c4ee74d5ca175d3cfa31a7ac4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54c589dc5aecacd3c80f563c8fffe117 = $(`&lt;div id=&quot;html_54c589dc5aecacd3c80f563c8fffe117&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rider: Ammar&lt;/div&gt;`)[0];
#                 popup_1e28a01c4ee74d5ca175d3cfa31a7ac4.setContent(html_54c589dc5aecacd3c80f563c8fffe117);
#
#
#
#         marker_2d1d04f6e0b7a3e997374e8655d40d07.bindPopup(popup_1e28a01c4ee74d5ca175d3cfa31a7ac4)
#         ;
#
#
#
#
#                 marker_2d1d04f6e0b7a3e997374e8655d40d07.setIcon(icon_9d8cc9e9a6caaf7e00519f1395cd6b7b);
#
#
#             var marker_72212f85ce2df58084f1a8a198599cac = L.marker(
#                 [48.732164, 9.114031],
#                 {
# }
#             ).addTo(ma
