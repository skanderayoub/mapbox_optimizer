# %%
from models import *
import requests
import folium
import folium.plugins
import uuid
from typing import List, Optional, Dict, Tuple
from IPython.display import display
import random

# Constants
MAPBOX_OPTIMIZATION_API_URL = "https://api.mapbox.com/optimized-trips/v1/mapbox/driving-traffic/"
MAPBOX_DIRECTIONS_API_URL = "https://api.mapbox.com/directions/v5/mapbox/driving-traffic/"
MAPBOX_ACCESS_TOKEN = "pk.eyJ1IjoicGVuZGxhIiwiYSI6ImNtOXNuNjV2NjAyNjYyanM5M2Fjb24xYTAifQ.7RqcSLC1TxVWdeZMj8QkTw"

# %%
class Test:
    """Test class for unit testing."""
    def __init__(self, optimizer: MapboxOptimizer):
        self.optimizer = optimizer

    def add_single_rider(self, driver: Driver, rider: Rider) -> None:
        """Test adding a single rider to a driver's ride."""
        print(f"\nAdding single rider {rider.name} to {driver.name}'s ride...")
        ride_manager = RideManager(self.optimizer)
        success = ride_manager.add_rider_to_ride(driver.ride, rider)
        if success:
            print(f"Successfully added {rider.name} to the ride.")
            # Step 4: Display updated ride
            print(f"\nUpdated Ride for {driver.name}:")
        else:
            print(f"Failed to add {rider.name} to the ride.")

    def add_riders_in_order(self, driver: Driver, riders: List[Rider]) -> None:
        """Test adding riders to a driver's ride in order."""
        print(f"\nAdding riders in order to {driver.name}'s ride...")
        ride_manager = RideManager(self.optimizer)
        for rider in riders:
            success = ride_manager.add_rider_to_ride(driver.ride, rider)
            if success:
                print(f"Successfully added {rider.name} to the ride.")
            else:
                print(f"Failed to add {rider.name} to the ride.")
        ride_manager.display_ride_info(driver.ride)

# %%
WORKPLACES = {
    "STIHL": [48.8315, 9.3095],
    "MERCEDES": [48.7833, 9.2250]
}

optimizer = MapboxOptimizer(MAPBOX_ACCESS_TOKEN)
ride_manager = RideManager(optimizer)

drivers = [
    Driver("Mohsen", [48.686722, 8.993101], WORKPLACES["STIHL"], "STIHL", max_detour_minutes=30, max_riders=3, optimizer=optimizer),
    Driver("Karim", [48.8316, 9.1670], WORKPLACES["STIHL"], "STIHL", max_detour_minutes=25, max_riders=2, optimizer=optimizer),
    Driver("Kamilia", [48.9000, 9.2000], WORKPLACES["STIHL"], "STIHL", max_detour_minutes=35, max_riders=4, optimizer=optimizer),
    Driver("Mahmoud", [48.7465, 9.1066], WORKPLACES["MERCEDES"], "MERCEDES", max_detour_minutes=20, max_riders=2, optimizer=optimizer),
    Driver("Skander", [48.7833, 9.1667], WORKPLACES["MERCEDES"], "MERCEDES", max_detour_minutes=50, max_riders=3, optimizer=optimizer),
]
riders = [
    Rider("Mongi", [48.7833, 9.1833], WORKPLACES["STIHL"], "STIHL"),
    Rider("Ammar", [48.6833, 9.0167], WORKPLACES["STIHL"], "STIHL"),
    Rider("Faya", [48.9100, 9.1400], WORKPLACES["STIHL"], "STIHL"),
    Rider("Samir", [48.7500, 9.1500], WORKPLACES["MERCEDES"], "MERCEDES"),
    Rider("Ghassen", [48.7400, 9.3000], WORKPLACES["MERCEDES"], "MERCEDES"),
]

# %%
test = Test(optimizer)
for i in range(3):
    driver = Driver("Mohsen", [48.686722, 8.993101], WORKPLACES["STIHL"], "STIHL", max_detour_minutes=30, max_riders=3, optimizer=optimizer)
    riders = [
        Rider("Mongi", [48.7833, 9.1833], WORKPLACES["STIHL"], "STIHL"),
        Rider("Ammar", [48.6833, 9.0167], WORKPLACES["STIHL"], "STIHL"),
        Rider("Faya", [48.9100, 9.1400], WORKPLACES["STIHL"], "STIHL"),
        Rider("Samir", [48.7500, 9.1500], WORKPLACES["MERCEDES"], "MERCEDES"),
        Rider("Ghassen", [48.7400, 9.3000], WORKPLACES["MERCEDES"], "MERCEDES"),
        Rider("Slim", [48.777490, 9.159607], WORKPLACES["STIHL"], "STIHL"),
        Rider("Fraj", [48.776868, 9.206385], WORKPLACES["STIHL"], "STIHL"),
        Rider("Khalil", [48.732164, 9.114031], WORKPLACES["STIHL"], "STIHL")
    ]
    random.shuffle(riders)
    test.add_riders_in_order(driver, riders)
# Out:
# Adding riders in order to Mohsen's ride...
# Successfully added Ammar to the ride.
# Rider Samir does not match workplace STIHL
# Failed to add Samir to the ride.
# Successfully added Khalil to the ride.
# Successfully added Mongi to the ride.
# Driver Mohsen's ride is full (max 3 riders).
# Failed to add Faya to the ride.
# Rider Ghassen does not match workplace STIHL
# Failed to add Ghassen to the ride.
# Driver Mohsen's ride is full (max 3 riders).
# Failed to add Fraj to the ride.
# Driver Mohsen's ride is full (max 3 riders).
# Failed to add Slim to the ride.
#
# ============================================================
# Ride Summary for Mohsen
# ============================================================
#
# General Information:
# - Driver: Mohsen
# - Workplace: STIHL (48.831500, 9.309500)
# - Max Riders: 3
# - Max Detour: 30.00 minutes
# - Riders: Ammar, Khalil, Mongi
# - Total Distance: 39.49 km
# - Total Duration: 63.23 minutes
# - Detour: 21.59 minutes
# - Direct Duration (no riders): 41.64 minutes
#
# Pickup Order:
# 1. Mohsen (Driver) at (48.686722, 8.993101)
# 2. Ammar (Rider) at (48.683300, 9.016700)
# 3. Khalil (Rider) at (48.732164, 9.114031)
# 4. Mongi (Rider) at (48.783300, 9.183300)
# 5. STIHL (Workplace) at (48.831500, 9.309500)
#
# Segment Durations:
# - Mohsen to Ammar: 5.74 minutes
# - Ammar to Khalil: 17.09 minutes
# - Khalil to Mongi: 18.35 minutes
# - Mongi to STIHL: 22.06 minutes
#
# Failed Assignment Attempts:
# - Rider Samir does not match workplace STIHL
# - Driver Mohsen's ride is full (max 3 riders)
# - Rider Ghassen does not match workplace STIHL
# - Driver Mohsen's ride is full (max 3 riders)
# - Driver Mohsen's ride is full (max 3 riders)
#
# Generating Route Map...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9b2acd7a45725e19258e54ea50a06ac5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9b2acd7a45725e19258e54ea50a06ac5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9b2acd7a45725e19258e54ea50a06ac5 = L.map(
#                 &quot;map_9b2acd7a45725e19258e54ea50a06ac5&quot;,
#                 {
#                     center: [48.743397200000004, 9.1233264],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_016e0835bdc97b6794331dfd1b3c886c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_016e0835bdc97b6794331dfd1b3c886c.addTo(map_9b2acd7a45725e19258e54ea50a06ac5);
#
#
#             var marker_51d860a2aa3323b3aaffbce8ed824a9d = L.marker(
#                 [48.686722, 8.993101],
#                 {
# }
#             ).addTo(map_9b2acd7a45725e19258e54ea50a06ac5);
#
#
#             var icon_f91a3a37d3d892b728c691938d357b2a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_1ed7bc5726c5b4330e294ebfe920c02f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f89e5d97f0ef736786d932f15de9e900 = $(`&lt;div id=&quot;html_f89e5d97f0ef736786d932f15de9e900&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Driver: Mohsen&lt;/div&gt;`)[0];
#                 popup_1ed7bc5726c5b4330e294ebfe920c02f.setContent(html_f89e5d97f0ef736786d932f15de9e900);
#
#
#
#         marker_51d860a2aa3323b3aaffbce8ed824a9d.bindPopup(popup_1ed7bc5726c5b4330e294ebfe920c02f)
#         ;
#
#
#
#
#                 marker_51d860a2aa3323b3aaffbce8ed824a9d.setIcon(icon_f91a3a37d3d892b728c691938d357b2a);
#
#
#             var marker_cb30466cce628cb42677af873649899e = L.marker(
#                 [48.6833, 9.0167],
#                 {
# }
#             ).addTo(map_9b2acd7a45725e19258e54ea50a06ac5);
#
#
#             var icon_e0107fa080a84cf494ccc3d3dc64aa3e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_55686452866668201070f3bb9775ce6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c06dec58d9c47d7b93c666549957c98 = $(`&lt;div id=&quot;html_0c06dec58d9c47d7b93c666549957c98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rider: Ammar&lt;/div&gt;`)[0];
#                 popup_55686452866668201070f3bb9775ce6a.setContent(html_0c06dec58d9c47d7b93c666549957c98);
#
#
#
#         marker_cb30466cce628cb42677af873649899e.bindPopup(popup_55686452866668201070f3bb9775ce6a)
#         ;
#
#
#
#
#                 marker_cb30466cce628cb42677af873649899e.setIcon(icon_e0107fa080a84cf494ccc3d3dc64aa3e);
#
#
#             var marker_90be9b957423ddf1c45b041e9752cf09 = L.marker(
#                 [48.732164, 9.114031],
#                 {
# }
#             ).addTo(map_9b2acd7a45725e19258e54ea50a06ac5);
#
#
#             var icon_07eebe40676df4eed5d4dacaa00ca3a2 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_82ceb719f73308d6af75af74e1a317f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d4040f0d152f820231211279d22cec6b = $(`&lt;div id=&quot;html_d4040f0d152f820231211279d22cec6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rider: Khalil&lt;/div&gt;`)[0];
#                 popup_82ceb719f73308d6af75af74e1a317f2.setContent(html_d4040f0d152f820231211279d22cec6b);
#
#
#
#         marker_90be9b957423ddf1c45b041e9752cf09.bindPopup(popup_82ceb719f73308d6af75af74e1a317f2)
#         ;
#
#
#
#
#                 marker_90be9b957423ddf1c45b041e9752cf09.setIcon(icon_07eebe40676df4eed5d4dacaa00ca3a2);
#
#
#             var marker_e5b8d70daf1e177336c2c92ea8749835 = L.marker(
#                 [48.7833, 9.1833],
#                 {
# }
#             ).addTo(m
# Adding riders in order to Mohsen's ride...
# Rider Ghassen does not match workplace STIHL
# Failed to add Ghassen to the ride.
# Successfully added Mongi to the ride.
# Successfully added Khalil to the ride.
# Adding Faya exceeds max detour of 30 minutes.
# Failed to add Faya to the ride.
# Rider Samir does not match workplace STIHL
# Failed to add Samir to the ride.
# Successfully added Slim to the ride.
# Driver Mohsen's ride is full (max 3 riders).
# Failed to add Ammar to the ride.
# Driver Mohsen's ride is full (max 3 riders).
# Failed to add Fraj to the ride.
#
# ============================================================
# Ride Summary for Mohsen
# ============================================================
#
# General Information:
# - Driver: Mohsen
# - Workplace: STIHL (48.831500, 9.309500)
# - Max Riders: 3
# - Max Detour: 30.00 minutes
# - Riders: Mongi, Khalil, Slim
# - Total Distance: 41.15 km
# - Total Duration: 63.51 minutes
# - Detour: 21.87 minutes
# - Direct Duration (no riders): 41.64 minutes
#
# Pickup Order:
# 1. Mohsen (Driver) at (48.686722, 8.993101)
# 2. Slim (Rider) at (48.777490, 9.159607)
# 3. Mongi (Rider) at (48.783300, 9.183300)
# 4. Khalil (Rider) at (48.732164, 9.114031)
# 5. STIHL (Workplace) at (48.831500, 9.309500)
#
# Segment Durations:
# - Mohsen to Slim: 15.99 minutes
# - Slim to Mongi: 16.91 minutes
# - Mongi to Khalil: 8.55 minutes
# - Khalil to STIHL: 22.06 minutes
#
# Failed Assignment Attempts:
# - Rider Ghassen does not match workplace STIHL
# - Adding Faya exceeds max detour of 30 minutes
# - Rider Samir does not match workplace STIHL
# - Driver Mohsen's ride is full (max 3 riders)
# - Driver Mohsen's ride is full (max 3 riders)
#
# Generating Route Map...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2f5da5adde1561a58e56286a0e72f9be {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2f5da5adde1561a58e56286a0e72f9be&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2f5da5adde1561a58e56286a0e72f9be = L.map(
#                 &quot;map_2f5da5adde1561a58e56286a0e72f9be&quot;,
#                 {
#                     center: [48.7622352, 9.1519078],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cc0b215be02e21633c36110763e867d3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cc0b215be02e21633c36110763e867d3.addTo(map_2f5da5adde1561a58e56286a0e72f9be);
#
#
#             var marker_0125524fb57f9b28363a9cf4f2466cd4 = L.marker(
#                 [48.686722, 8.993101],
#                 {
# }
#             ).addTo(map_2f5da5adde1561a58e56286a0e72f9be);
#
#
#             var icon_968ad5ef5bda4391d4584204f1245391 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_0810eac98c1105762f0f3b2264c30d62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5434527c4960ffc32e934e545636a89 = $(`&lt;div id=&quot;html_f5434527c4960ffc32e934e545636a89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Driver: Mohsen&lt;/div&gt;`)[0];
#                 popup_0810eac98c1105762f0f3b2264c30d62.setContent(html_f5434527c4960ffc32e934e545636a89);
#
#
#
#         marker_0125524fb57f9b28363a9cf4f2466cd4.bindPopup(popup_0810eac98c1105762f0f3b2264c30d62)
#         ;
#
#
#
#
#                 marker_0125524fb57f9b28363a9cf4f2466cd4.setIcon(icon_968ad5ef5bda4391d4584204f1245391);
#
#
#             var marker_da895c3f9e95b80de789007a366d4003 = L.marker(
#                 [48.7833, 9.1833],
#                 {
# }
#             ).addTo(map_2f5da5adde1561a58e56286a0e72f9be);
#
#
#             var icon_cc6e40b9a100f165d27bf4bbbe70dcee = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_7a93f9778e7bbea957fdd9d51c658ec1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1bce98333ce018966288af154142400d = $(`&lt;div id=&quot;html_1bce98333ce018966288af154142400d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rider: Mongi&lt;/div&gt;`)[0];
#                 popup_7a93f9778e7bbea957fdd9d51c658ec1.setContent(html_1bce98333ce018966288af154142400d);
#
#
#
#         marker_da895c3f9e95b80de789007a366d4003.bindPopup(popup_7a93f9778e7bbea957fdd9d51c658ec1)
#         ;
#
#
#
#
#                 marker_da895c3f9e95b80de789007a366d4003.setIcon(icon_cc6e40b9a100f165d27bf4bbbe70dcee);
#
#
#             var marker_8416943b41b9ec9561895dba22ea649e = L.marker(
#                 [48.732164, 9.114031],
#                 {
# }
#             ).addTo(map_2f5da5adde1561a58e56286a0e72f9be);
#
#
#             var icon_8526f7530b3113118c10e8619f95f396 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_67451bf50413ca2b82f2bca166a02bd4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ef9f3563b369818f7b74ad6b66b3967 = $(`&lt;div id=&quot;html_4ef9f3563b369818f7b74ad6b66b3967&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rider: Khalil&lt;/div&gt;`)[0];
#                 popup_67451bf50413ca2b82f2bca166a02bd4.setContent(html_4ef9f3563b369818f7b74ad6b66b3967);
#
#
#
#         marker_8416943b41b9ec9561895dba22ea649e.bindPopup(popup_67451bf50413ca2b82f2bca166a02bd4)
#         ;
#
#
#
#
#                 marker_8416943b41b9ec9561895dba22ea649e.setIcon(icon_8526f7530b3113118c10e8619f95f396);
#
#
#             var marker_b0c11b6fa4cbc23b304929dc65ebd65b = L.marker(
#                 [48.77749, 9.159607],
#                 {
# }
#             ).addTo(map_2f
# Adding riders in order to Mohsen's ride...
# Successfully added Slim to the ride.
# Adding Faya exceeds max detour of 30 minutes.
# Failed to add Faya to the ride.
# Successfully added Ammar to the ride.
# Successfully added Fraj to the ride.
# Rider Samir does not match workplace STIHL
# Failed to add Samir to the ride.
# Driver Mohsen's ride is full (max 3 riders).
# Failed to add Mongi to the ride.
# Driver Mohsen's ride is full (max 3 riders).
# Failed to add Khalil to the ride.
# Rider Ghassen does not match workplace STIHL
# Failed to add Ghassen to the ride.
#
# ============================================================
# Ride Summary for Mohsen
# ============================================================
#
# General Information:
# - Driver: Mohsen
# - Workplace: STIHL (48.831500, 9.309500)
# - Max Riders: 3
# - Max Detour: 30.00 minutes
# - Riders: Slim, Ammar, Fraj
# - Total Distance: 40.49 km
# - Total Duration: 63.20 minutes
# - Detour: 21.55 minutes
# - Direct Duration (no riders): 41.64 minutes
#
# Pickup Order:
# 1. Mohsen (Driver) at (48.686722, 8.993101)
# 2. Ammar (Rider) at (48.683300, 9.016700)
# 3. Slim (Rider) at (48.777490, 9.159607)
# 4. Fraj (Rider) at (48.776868, 9.206385)
# 5. STIHL (Workplace) at (48.831500, 9.309500)
#
# Segment Durations:
# - Mohsen to Ammar: 5.74 minutes
# - Ammar to Slim: 25.64 minutes
# - Slim to Fraj: 13.22 minutes
# - Fraj to STIHL: 18.60 minutes
#
# Failed Assignment Attempts:
# - Adding Faya exceeds max detour of 30 minutes
# - Rider Samir does not match workplace STIHL
# - Driver Mohsen's ride is full (max 3 riders)
# - Driver Mohsen's ride is full (max 3 riders)
# - Rider Ghassen does not match workplace STIHL
#
# Generating Route Map...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_76a784c75cbbbc6e1248eab8064bbda1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_76a784c75cbbbc6e1248eab8064bbda1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_76a784c75cbbbc6e1248eab8064bbda1 = L.map(
#                 &quot;map_76a784c75cbbbc6e1248eab8064bbda1&quot;,
#                 {
#                     center: [48.751176, 9.1370586],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eba7cb289a964fa518ac2c659c87330e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eba7cb289a964fa518ac2c659c87330e.addTo(map_76a784c75cbbbc6e1248eab8064bbda1);
#
#
#             var marker_284cb217e4cec7ba91d089161494d9f9 = L.marker(
#                 [48.686722, 8.993101],
#                 {
# }
#             ).addTo(map_76a784c75cbbbc6e1248eab8064bbda1);
#
#
#             var icon_9b98ff1883f9e52161ac46f0d3595ac8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_0521c8eadd7ce6e51dce5d7c6bd6c561 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe79fab6c5d1f14a1e98026c8b5afcb7 = $(`&lt;div id=&quot;html_fe79fab6c5d1f14a1e98026c8b5afcb7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Driver: Mohsen&lt;/div&gt;`)[0];
#                 popup_0521c8eadd7ce6e51dce5d7c6bd6c561.setContent(html_fe79fab6c5d1f14a1e98026c8b5afcb7);
#
#
#
#         marker_284cb217e4cec7ba91d089161494d9f9.bindPopup(popup_0521c8eadd7ce6e51dce5d7c6bd6c561)
#         ;
#
#
#
#
#                 marker_284cb217e4cec7ba91d089161494d9f9.setIcon(icon_9b98ff1883f9e52161ac46f0d3595ac8);
#
#
#             var marker_ba68170584b0455344efac98e620f50f = L.marker(
#                 [48.77749, 9.159607],
#                 {
# }
#             ).addTo(map_76a784c75cbbbc6e1248eab8064bbda1);
#
#
#             var icon_c44f08e1074ddce651da809fcacdc8c3 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_271265c5c93881329dca0698b4280243 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4e52ee9ec42f3103efcd7d442492d23 = $(`&lt;div id=&quot;html_b4e52ee9ec42f3103efcd7d442492d23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rider: Slim&lt;/div&gt;`)[0];
#                 popup_271265c5c93881329dca0698b4280243.setContent(html_b4e52ee9ec42f3103efcd7d442492d23);
#
#
#
#         marker_ba68170584b0455344efac98e620f50f.bindPopup(popup_271265c5c93881329dca0698b4280243)
#         ;
#
#
#
#
#                 marker_ba68170584b0455344efac98e620f50f.setIcon(icon_c44f08e1074ddce651da809fcacdc8c3);
#
#
#             var marker_179de33e5db15b1766d7afa093939ca2 = L.marker(
#                 [48.6833, 9.0167],
#                 {
# }
#             ).addTo(map_76a784c75cbbbc6e1248eab8064bbda1);
#
#
#             var icon_e1984d9332cdad3a032be0a9cba0a0a3 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_350fdc25739dd6b75d928c5eb7caab91 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90a8f82cf19df0948f3631f356a90639 = $(`&lt;div id=&quot;html_90a8f82cf19df0948f3631f356a90639&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rider: Ammar&lt;/div&gt;`)[0];
#                 popup_350fdc25739dd6b75d928c5eb7caab91.setContent(html_90a8f82cf19df0948f3631f356a90639);
#
#
#
#         marker_179de33e5db15b1766d7afa093939ca2.bindPopup(popup_350fdc25739dd6b75d928c5eb7caab91)
#         ;
#
#
#
#
#                 marker_179de33e5db15b1766d7afa093939ca2.setIcon(icon_e1984d9332cdad3a032be0a9cba0a0a3);
#
#
#             var marker_abc3786180ee6352e8af8891806d37a8 = L.marker(
#                 [48.776868, 9.206385],
#                 {
# }
#             ).addTo(map_76a78

# %%
test = Test(optimizer)
for i in range(3):
    driver = Driver("Kamilia", [48.9000, 9.2000], WORKPLACES["STIHL"], "STIHL", max_detour_minutes=35, max_riders=4, optimizer=optimizer)
    riders = [
        Rider("Mongi", [48.7833, 9.1833], WORKPLACES["STIHL"], "STIHL"),
        Rider("Ammar", [48.6833, 9.0167], WORKPLACES["STIHL"], "STIHL"),
        Rider("Faya", [48.9100, 9.1400], WORKPLACES["STIHL"], "STIHL"),
        Rider("Samir", [48.7500, 9.1500], WORKPLACES["MERCEDES"], "MERCEDES"),
        Rider("Ghassen", [48.7400, 9.3000], WORKPLACES["MERCEDES"], "MERCEDES"),
        Rider("Slim", [48.777490, 9.159607], WORKPLACES["STIHL"], "STIHL"),
        Rider("Fraj", [48.776868, 9.206385], WORKPLACES["STIHL"], "STIHL"),
        Rider("Khalil", [48.732164, 9.114031], WORKPLACES["STIHL"], "STIHL")
    ]
    random.shuffle(riders)
    test.add_riders_in_order(driver, riders)
# Out:
# Adding riders in order to Kamilia's ride...
# Successfully added Fraj to the ride.
# Adding Slim exceeds max detour of 35 minutes.
# Failed to add Slim to the ride.
# Successfully added Mongi to the ride.
# Adding Khalil exceeds max detour of 35 minutes.
# Failed to add Khalil to the ride.
# Rider Samir does not match workplace STIHL
# Failed to add Samir to the ride.
# Adding Ammar exceeds max detour of 35 minutes.
# Failed to add Ammar to the ride.
# Adding Faya exceeds max detour of 35 minutes.
# Failed to add Faya to the ride.
# Rider Ghassen does not match workplace STIHL
# Failed to add Ghassen to the ride.
#
# ============================================================
# Ride Summary for Kamilia
# ============================================================
#
# General Information:
# - Driver: Kamilia
# - Workplace: STIHL (48.831500, 9.309500)
# - Max Riders: 4
# - Max Detour: 35.00 minutes
# - Riders: Fraj, Mongi
# - Total Distance: 30.81 km
# - Total Duration: 54.04 minutes
# - Detour: 31.91 minutes
# - Direct Duration (no riders): 22.14 minutes
#
# Pickup Order:
# 1. Kamilia (Driver) at (48.900000, 9.200000)
# 2. Mongi (Rider) at (48.783300, 9.183300)
# 3. Fraj (Rider) at (48.776868, 9.206385)
# 4. STIHL (Workplace) at (48.831500, 9.309500)
#
# Segment Durations:
# - Kamilia to Mongi: 27.54 minutes
# - Mongi to Fraj: 7.91 minutes
# - Fraj to STIHL: 18.60 minutes
#
# Failed Assignment Attempts:
# - Adding Slim exceeds max detour of 35 minutes
# - Adding Khalil exceeds max detour of 35 minutes
# - Rider Samir does not match workplace STIHL
# - Adding Ammar exceeds max detour of 35 minutes
# - Adding Faya exceeds max detour of 35 minutes
# - Rider Ghassen does not match workplace STIHL
#
# Generating Route Map...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8fff474c7dec7710e06c83d71f05c4d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8fff474c7dec7710e06c83d71f05c4d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8fff474c7dec7710e06c83d71f05c4d5 = L.map(
#                 &quot;map_8fff474c7dec7710e06c83d71f05c4d5&quot;,
#                 {
#                     center: [48.822917000000004, 9.22479625],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_debcd7081431f3cd659408b0aa0fa823 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_debcd7081431f3cd659408b0aa0fa823.addTo(map_8fff474c7dec7710e06c83d71f05c4d5);
#
#
#             var marker_5ba1bc5c71abd30bdc9ab0c44b463918 = L.marker(
#                 [48.9, 9.2],
#                 {
# }
#             ).addTo(map_8fff474c7dec7710e06c83d71f05c4d5);
#
#
#             var icon_1e40acea874c1aacdbe11f5d99d76074 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_b1d5c316504f8fe4c69af6f619bfaf8c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26b4db7d3af4af594d8cd2000cfa5dc8 = $(`&lt;div id=&quot;html_26b4db7d3af4af594d8cd2000cfa5dc8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Driver: Kamilia&lt;/div&gt;`)[0];
#                 popup_b1d5c316504f8fe4c69af6f619bfaf8c.setContent(html_26b4db7d3af4af594d8cd2000cfa5dc8);
#
#
#
#         marker_5ba1bc5c71abd30bdc9ab0c44b463918.bindPopup(popup_b1d5c316504f8fe4c69af6f619bfaf8c)
#         ;
#
#
#
#
#                 marker_5ba1bc5c71abd30bdc9ab0c44b463918.setIcon(icon_1e40acea874c1aacdbe11f5d99d76074);
#
#
#             var marker_6f515fd7c64884eec5a09f0ae4026a8a = L.marker(
#                 [48.776868, 9.206385],
#                 {
# }
#             ).addTo(map_8fff474c7dec7710e06c83d71f05c4d5);
#
#
#             var icon_685e02c93f55dc6119da22b744a22176 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_844a715b4d370a5a66f8d86e0fc7662f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58bebce612fb964851cbda191e9c7f6e = $(`&lt;div id=&quot;html_58bebce612fb964851cbda191e9c7f6e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rider: Fraj&lt;/div&gt;`)[0];
#                 popup_844a715b4d370a5a66f8d86e0fc7662f.setContent(html_58bebce612fb964851cbda191e9c7f6e);
#
#
#
#         marker_6f515fd7c64884eec5a09f0ae4026a8a.bindPopup(popup_844a715b4d370a5a66f8d86e0fc7662f)
#         ;
#
#
#
#
#                 marker_6f515fd7c64884eec5a09f0ae4026a8a.setIcon(icon_685e02c93f55dc6119da22b744a22176);
#
#
#             var marker_077f25a0cc583d208d426159383db900 = L.marker(
#                 [48.7833, 9.1833],
#                 {
# }
#             ).addTo(map_8fff474c7dec7710e06c83d71f05c4d5);
#
#
#             var icon_89dea76020b51e175ded2f1474562913 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_77c83f759f92c01e317c2e9cb5deb096 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_782b4ffe8f9f157c66d8a1a41e4fdbde = $(`&lt;div id=&quot;html_782b4ffe8f9f157c66d8a1a41e4fdbde&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rider: Mongi&lt;/div&gt;`)[0];
#                 popup_77c83f759f92c01e317c2e9cb5deb096.setContent(html_782b4ffe8f9f157c66d8a1a41e4fdbde);
#
#
#
#         marker_077f25a0cc583d208d426159383db900.bindPopup(popup_77c83f759f92c01e317c2e9cb5deb096)
#         ;
#
#
#
#
#                 marker_077f25a0cc583d208d426159383db900.setIcon(icon_89dea76020b51e175ded2f1474562913);
#
#
#             var marker_3da7356a21c6095dd1034b8c611ad579 = L.marker(
#                 [48.8315, 9.3095],
#                 {
# }
#             ).addTo(map_8fff474
# Adding riders in order to Kamilia's ride...
# Rider Samir does not match workplace STIHL
# Failed to add Samir to the ride.
# Successfully added Faya to the ride.
# Adding Slim exceeds max detour of 35 minutes.
# Failed to add Slim to the ride.
# Rider Ghassen does not match workplace STIHL
# Failed to add Ghassen to the ride.
# Adding Mongi exceeds max detour of 35 minutes.
# Failed to add Mongi to the ride.
# Adding Khalil exceeds max detour of 35 minutes.
# Failed to add Khalil to the ride.
# Adding Ammar exceeds max detour of 35 minutes.
# Failed to add Ammar to the ride.
# Adding Fraj exceeds max detour of 35 minutes.
# Failed to add Fraj to the ride.
#
# ============================================================
# Ride Summary for Kamilia
# ============================================================
#
# General Information:
# - Driver: Kamilia
# - Workplace: STIHL (48.831500, 9.309500)
# - Max Riders: 4
# - Max Detour: 35.00 minutes
# - Riders: Faya
# - Total Distance: 24.01 km
# - Total Duration: 49.57 minutes
# - Detour: 27.43 minutes
# - Direct Duration (no riders): 22.14 minutes
#
# Pickup Order:
# 1. Kamilia (Driver) at (48.900000, 9.200000)
# 2. Faya (Rider) at (48.910000, 9.140000)
# 3. STIHL (Workplace) at (48.831500, 9.309500)
#
# Segment Durations:
# - Kamilia to Faya: 17.15 minutes
# - Faya to STIHL: 32.42 minutes
#
# Failed Assignment Attempts:
# - Rider Samir does not match workplace STIHL
# - Adding Slim exceeds max detour of 35 minutes
# - Rider Ghassen does not match workplace STIHL
# - Adding Mongi exceeds max detour of 35 minutes
# - Adding Khalil exceeds max detour of 35 minutes
# - Adding Ammar exceeds max detour of 35 minutes
# - Adding Fraj exceeds max detour of 35 minutes
#
# Generating Route Map...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e92303ee60521f9753e4ef93c29aaa1f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e92303ee60521f9753e4ef93c29aaa1f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e92303ee60521f9753e4ef93c29aaa1f = L.map(
#                 &quot;map_e92303ee60521f9753e4ef93c29aaa1f&quot;,
#                 {
#                     center: [48.880500000000005, 9.2165],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c00572c86ae6f2fd697b263b4c8e8ff8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c00572c86ae6f2fd697b263b4c8e8ff8.addTo(map_e92303ee60521f9753e4ef93c29aaa1f);
#
#
#             var marker_e7ded4ea43dfdaac04f09a4ecd0756b3 = L.marker(
#                 [48.9, 9.2],
#                 {
# }
#             ).addTo(map_e92303ee60521f9753e4ef93c29aaa1f);
#
#
#             var icon_eed3fbc1430de724fec902b60ab6449d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8212419f10692b3b23fc7ab65c5b85b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30b54013e1b687f3328c30aa86625796 = $(`&lt;div id=&quot;html_30b54013e1b687f3328c30aa86625796&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Driver: Kamilia&lt;/div&gt;`)[0];
#                 popup_8212419f10692b3b23fc7ab65c5b85b0.setContent(html_30b54013e1b687f3328c30aa86625796);
#
#
#
#         marker_e7ded4ea43dfdaac04f09a4ecd0756b3.bindPopup(popup_8212419f10692b3b23fc7ab65c5b85b0)
#         ;
#
#
#
#
#                 marker_e7ded4ea43dfdaac04f09a4ecd0756b3.setIcon(icon_eed3fbc1430de724fec902b60ab6449d);
#
#
#             var marker_f59f8035ddaea2bd5551c9b622f93fa9 = L.marker(
#                 [48.91, 9.14],
#                 {
# }
#             ).addTo(map_e92303ee60521f9753e4ef93c29aaa1f);
#
#
#             var icon_2792e8e4e4d1092c6d1489b5e07f6f27 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_fdfc113e84b4e402d4ba62513d7d8137 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6cad892e18e0b8b777836e06b6ab6bb0 = $(`&lt;div id=&quot;html_6cad892e18e0b8b777836e06b6ab6bb0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rider: Faya&lt;/div&gt;`)[0];
#                 popup_fdfc113e84b4e402d4ba62513d7d8137.setContent(html_6cad892e18e0b8b777836e06b6ab6bb0);
#
#
#
#         marker_f59f8035ddaea2bd5551c9b622f93fa9.bindPopup(popup_fdfc113e84b4e402d4ba62513d7d8137)
#         ;
#
#
#
#
#                 marker_f59f8035ddaea2bd5551c9b622f93fa9.setIcon(icon_2792e8e4e4d1092c6d1489b5e07f6f27);
#
#
#             var marker_4851e821268dd0f69e98c05a77301c63 = L.marker(
#                 [48.8315, 9.3095],
#                 {
# }
#             ).addTo(map_e92303ee60521f9753e4ef93c29aaa1f);
#
#
#             var icon_24dc8634d00a373df0b6f31bf23ef99f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8919924119335e612b319109d6c78a32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04b6b575b202435b96f44500180f6c54 = $(`&lt;div id=&quot;html_04b6b575b202435b96f44500180f6c54&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Workplace: STIHL&lt;/div&gt;`)[0];
#                 popup_8919924119335e612b319109d6c78a32.setContent(html_04b6b575b202435b96f44500180f6c54);
#
#
#
#         marker_4851e821268dd0f69e98c05a77301c63.bindPopup(popup_8919924119335e612b319109d6c78a32)
#         ;
#
#
#
#
#                 marker_4851e821268dd0f69e98c05a77301c63.setIcon(icon_24dc8634d00a373df0b6f31bf23ef99f);
#
#
#             ant_path_f5ccf8f29f3728ec1e5a922226247737 = L.polyline.antPath(
#               [[48.899315, 9.199665], [48.898352, 9.199703], [48.898013, 9.20114], [48.8
# Adding riders in order to Kamilia's ride...
# Adding Slim exceeds max detour of 35 minutes.
# Failed to add Slim to the ride.
# Successfully added Mongi to the ride.
# Adding Khalil exceeds max detour of 35 minutes.
# Failed to add Khalil to the ride.
# Adding Ammar exceeds max detour of 35 minutes.
# Failed to add Ammar to the ride.
# Adding Faya exceeds max detour of 35 minutes.
# Failed to add Faya to the ride.
# Rider Samir does not match workplace STIHL
# Failed to add Samir to the ride.
# Successfully added Fraj to the ride.
# Rider Ghassen does not match workplace STIHL
# Failed to add Ghassen to the ride.
#
# ============================================================
# Ride Summary for Kamilia
# ============================================================
#
# General Information:
# - Driver: Kamilia
# - Workplace: STIHL (48.831500, 9.309500)
# - Max Riders: 4
# - Max Detour: 35.00 minutes
# - Riders: Mongi, Fraj
# - Total Distance: 30.81 km
# - Total Duration: 54.04 minutes
# - Detour: 31.91 minutes
# - Direct Duration (no riders): 22.14 minutes
#
# Pickup Order:
# 1. Kamilia (Driver) at (48.900000, 9.200000)
# 2. Mongi (Rider) at (48.783300, 9.183300)
# 3. Fraj (Rider) at (48.776868, 9.206385)
# 4. STIHL (Workplace) at (48.831500, 9.309500)
#
# Segment Durations:
# - Kamilia to Mongi: 27.54 minutes
# - Mongi to Fraj: 7.91 minutes
# - Fraj to STIHL: 18.60 minutes
#
# Failed Assignment Attempts:
# - Adding Slim exceeds max detour of 35 minutes
# - Adding Khalil exceeds max detour of 35 minutes
# - Adding Ammar exceeds max detour of 35 minutes
# - Adding Faya exceeds max detour of 35 minutes
# - Rider Samir does not match workplace STIHL
# - Rider Ghassen does not match workplace STIHL
#
# Generating Route Map...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3af9c1dd7fb8c1895244ca2216fdb36d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3af9c1dd7fb8c1895244ca2216fdb36d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3af9c1dd7fb8c1895244ca2216fdb36d = L.map(
#                 &quot;map_3af9c1dd7fb8c1895244ca2216fdb36d&quot;,
#                 {
#                     center: [48.822917000000004, 9.224796249999999],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1c9fd69674e0421b40743668e02215c5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1c9fd69674e0421b40743668e02215c5.addTo(map_3af9c1dd7fb8c1895244ca2216fdb36d);
#
#
#             var marker_185ee7d49e02072e04e3c0960c66057b = L.marker(
#                 [48.9, 9.2],
#                 {
# }
#             ).addTo(map_3af9c1dd7fb8c1895244ca2216fdb36d);
#
#
#             var icon_d0863b2dc17373235668aed005d18f13 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4cd2d3426e0609d8aba9aa2dc79d734e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e35d7ed470e2a9cb2cb8b916e9943f81 = $(`&lt;div id=&quot;html_e35d7ed470e2a9cb2cb8b916e9943f81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Driver: Kamilia&lt;/div&gt;`)[0];
#                 popup_4cd2d3426e0609d8aba9aa2dc79d734e.setContent(html_e35d7ed470e2a9cb2cb8b916e9943f81);
#
#
#
#         marker_185ee7d49e02072e04e3c0960c66057b.bindPopup(popup_4cd2d3426e0609d8aba9aa2dc79d734e)
#         ;
#
#
#
#
#                 marker_185ee7d49e02072e04e3c0960c66057b.setIcon(icon_d0863b2dc17373235668aed005d18f13);
#
#
#             var marker_c083333014f38ae4ca477c4a3fedd3bb = L.marker(
#                 [48.7833, 9.1833],
#                 {
# }
#             ).addTo(map_3af9c1dd7fb8c1895244ca2216fdb36d);
#
#
#             var icon_490aa45c173551fa5403f9b86bc5f5f7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_db41b4bd92d5cac44e11834c750dde4e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_818a821f1f5d5fee1bffcd83127b04c2 = $(`&lt;div id=&quot;html_818a821f1f5d5fee1bffcd83127b04c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rider: Mongi&lt;/div&gt;`)[0];
#                 popup_db41b4bd92d5cac44e11834c750dde4e.setContent(html_818a821f1f5d5fee1bffcd83127b04c2);
#
#
#
#         marker_c083333014f38ae4ca477c4a3fedd3bb.bindPopup(popup_db41b4bd92d5cac44e11834c750dde4e)
#         ;
#
#
#
#
#                 marker_c083333014f38ae4ca477c4a3fedd3bb.setIcon(icon_490aa45c173551fa5403f9b86bc5f5f7);
#
#
#             var marker_0aaec8122db8e3bab5a45f6ce148065b = L.marker(
#                 [48.776868, 9.206385],
#                 {
# }
#             ).addTo(map_3af9c1dd7fb8c1895244ca2216fdb36d);
#
#
#             var icon_e7175de9d25f911af19d9e254b9ebd71 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_054e5aa489ad451848504c0978f35444 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2e3877215129cbbc384785044f0cd1a = $(`&lt;div id=&quot;html_a2e3877215129cbbc384785044f0cd1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rider: Fraj&lt;/div&gt;`)[0];
#                 popup_054e5aa489ad451848504c0978f35444.setContent(html_a2e3877215129cbbc384785044f0cd1a);
#
#
#
#         marker_0aaec8122db8e3bab5a45f6ce148065b.bindPopup(popup_054e5aa489ad451848504c0978f35444)
#         ;
#
#
#
#
#                 marker_0aaec8122db8e3bab5a45f6ce148065b.setIcon(icon_e7175de9d25f911af19d9e254b9ebd71);
#
#
#             var marker_648e7d5c118a8ce107f4443a23fd8cfa = L.marker(
#                 [48.8315, 9.3095],
#                 {
# }
#             ).addTo(map_
